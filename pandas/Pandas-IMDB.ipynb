# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('/Users/amb/Downloads/movies.csv')
directors = pd.read_csv('/Users/amb/Downloads/directors.csv')

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue
# 0              0  43597  237000000         150  2787965087  \
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800  \
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
directors
# Out:
#       Unnamed: 0      director_name    id gender
# 0              0      James Cameron  4762   Male
# 1              1     Gore Verbinski  4763   Male
# 2              2         Sam Mendes  4764   Male
# 3              3  Christopher Nolan  4765   Male
# 4              4     Andrew Stanton  4766   Male
# ...          ...                ...   ...    ...
# 2344        2344      Shane Carruth  7106   Male
# 2345        2345   Neill Dela Llana  7107    NaN
# 2346        2346        Scott Smith  7108    NaN
# 2347        2347        Daniel Hsia  7109   Male
# 2348        2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 4 columns]

# %%
movies.merge(directors,on="id")
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, id, budget, popularity, revenue, title, vote_average, vote_count, director_id, year, month, day, Unnamed: 0_y, director_name, gender]
# Index: []

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue
# 0              0  43597  237000000         150  2787965087  \
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800  \
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movies
# Out:
#       Unnamed: 0     id     budget  popularity     revenue
# 0              0  43597  237000000         150  2787965087  \
# 1              1  43598  300000000         139   961000000
# 2              2  43599  245000000         107   880674609
# 3              3  43600  250000000         112  1084939099
# 4              5  43602  258000000         115   890871626
# ...          ...    ...        ...         ...         ...
# 1460        4736  48363          0           3      321952
# 1461        4743  48370      27000          19     3151130
# 1462        4748  48375          0           7           0
# 1463        4749  48376          0           3           0
# 1464        4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800  \
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# ...

# %%
movies.columns
# Out:
# Index(['Unnamed: 0', 'id', 'budget', 'popularity', 'revenue', 'title',
#        'vote_average', 'vote_count', 'director_id', 'year', 'month', 'day'],
#       dtype='object')

# %%
movies.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
directors.drop(columns = ['Unnamed: 0'],inplace=True)

# %%
data = movies.merge(directors,left_on="director_id",right_on='id', how = 'inner')

# %%
movies["director_id"].nunique()
# Out:
# 199

# %%
directors['id'].nunique()
# Out:
# 2349

# %%
np.all(movies["director_id"].isin(directors["id"]))
# Out:
# True

# %%
# Out:
#          id     budget  popularity     revenue
# 0     43597  237000000         150  2787965087  \
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count
# 0                                       Avatar           7.2       11800  \
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data
# Out:
#        id_x     budget  popularity     revenue                       title
# 0     43597  237000000         150  2787965087                      Avatar  \
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
# ...     ...        ...         ...         ...                         ...
# 1460  46859          0          14    25288872                 Enough Said
# 1461  47023    6500000          11    13368437          Friends with Money
# 1462  47524    3000000           5           0                 Please Give
# 1463  47962          0           0           0         Walking and Talking
# 1464  48229     250000           1     4186931            Lovely & Amazing
#
#       vote_average  vote_count  director_id  year month        day
# ...

# %%
data.rename({"id_x":"movie_id"}, inplace=True)

# %%
data.drop(columns=['director_id','id_y'],inplace=True)

# %%
data.rename(columns={'id_x':'movie_id'},inplace=True)

# %%
data
# Out:
#       movie_id     budget  popularity     revenue                       title
# 0        43597  237000000         150  2787965087                      Avatar  \
# 1        43622  200000000         100  1845034188                     Titanic
# 2        43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3        43879  115000000          38   378882411                   True Lies
# 4        44184   70000000          24    90000098                   The Abyss
# ...        ...        ...         ...         ...                         ...
# 1460     46859          0          14    25288872                 Enough Said
# 1461     47023    6500000          11    13368437          Friends with Money
# 1462     47524    3000000           5           0                 Please Give
# 1463     47962          0           0           0         Walking and Talking
# 1464     48229     250000           1     4186931            Lovely & Amazing
#
# ...

# %%
data.shape
# Out:
# (1465, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1465 entries, 0 to 1464
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       1465 non-null   int64
#  1   budget         1465 non-null   int64
#  2   popularity     1465 non-null   int64
#  3   revenue        1465 non-null   int64
#  4   title          1465 non-null   object
#  5   vote_average   1465 non-null   float64
#  6   vote_count     1465 non-null   int64
#  7   year           1465 non-null   int64
#  8   month          1465 non-null   object
#  9   day            1465 non-null   object
#  10  director_name  1465 non-null   object
#  11  gender         1341 non-null   object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 148.8+ KB

# %%
data.head()
# Out:
#    movie_id     budget  popularity     revenue                       title
# 0     43597  237000000         150  2787965087                      Avatar  \
# 1     43622  200000000         100  1845034188                     Titanic
# 2     43876  100000000         101   520000000  Terminator 2: Judgment Day
# 3     43879  115000000          38   378882411                   True Lies
# 4     44184   70000000          24    90000098                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
data['budget'] = (data['budget']/1000000).round(2)

# %%
data['revenue'] = (data['revenue']/1000000).round(2)

# %%
data.head()
# Out:
#    movie_id  budget  popularity  revenue                       title
# 0     43597   237.0         150  2787.97                      Avatar  \
# 1     43622   200.0         100  1845.03                     Titanic
# 2     43876   100.0         101   520.00  Terminator 2: Judgment Day
# 3     43879   115.0          38   378.88                   True Lies
# 4     44184    70.0          24    90.00                   The Abyss
#
#    vote_average  vote_count  year month        day  director_name gender
# 0           7.2       11800  2009   Dec   Thursday  James Cameron   Male
# 1           7.5        7562  1997   Nov    Tuesday  James Cameron   Male
# 2           7.7        4185  1991   Jul     Monday  James Cameron   Male
# 3           6.8        1116  1994   Jul   Thursday  James Cameron   Male
# 4           7.1         808  1989   Aug  Wednesday  James Cameron   Male

# %%
data.rename(columns={'budget':"budget_mm_$",'revenue':"revenue_mm_$"},inplace=True)

# %%
data
# Out:
#       movie_id  budget_mm_$  popularity  revenue_mm_$
# 0        43597       237.00         150       2787.97  \
# 1        43622       200.00         100       1845.03
# 2        43876       100.00         101        520.00
# 3        43879       115.00          38        378.88
# 4        44184        70.00          24         90.00
# ...        ...          ...         ...           ...
# 1460     46859         0.00          14         25.29
# 1461     47023         6.50          11         13.37
# 1462     47524         3.00           5          0.00
# 1463     47962         0.00           0          0.00
# 1464     48229         0.25           1          4.19
#
#                            title  vote_average  vote_count  year month
# 0                         Avatar           7.2       11800  2009   Dec  \
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
data[data["vote_average"]>7]
# Out:
#       movie_id  budget_mm_$  popularity  revenue_mm_$
# 0        43597       237.00         150       2787.97  \
# 1        43622       200.00         100       1845.03
# 2        43876       100.00         101        520.00
# 4        44184        70.00          24         90.00
# 5        46000        18.50          67        183.32
# ...        ...          ...         ...           ...
# 1424     47488         4.00          11         35.56
# 1426     48310         0.16           3          6.71
# 1433     46168        11.50          15         23.24
# 1438     47597         0.00          11          0.00
# 1441     47232         5.00          35          8.20
#
#                            title  vote_average  vote_count  year month
# 0                         Avatar           7.2       11800  2009   Dec  \
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
data.loc[(data['vote_average']>7) & (data['year']>2000),['title','director_name']]
# Out:
#                                                   title      director_name
# 0                                                Avatar      James Cameron
# 11    Pirates of the Caribbean: The Curse of the Bla...     Gore Verbinski
# 16                                    Road to Perdition         Sam Mendes
# 21                                The Dark Knight Rises  Christopher Nolan
# 22                                      The Dark Knight  Christopher Nolan
# ...                                                 ...                ...
# 1386                                    Before Midnight  Richard Linklater
# 1388                                      Before Sunset  Richard Linklater
# 1422                                              Sicko      Michael Moore
# 1424                              Bowling for Columbine      Michael Moore
# 1441                                      The Machinist      Brad Anderson
#
# [153 rows x 2 columns]

# %%
data.loc[(data['director_name'] == "Christopher Nolan"),['title','year']]
# Out:
#                     title  year
# 21  The Dark Knight Rises  2012
# 22        The Dark Knight  2008
# 23           Interstellar  2014
# 24              Inception  2010
# 25          Batman Begins  2005
# 26               Insomnia  2002
# 27           The Prestige  2006
# 28                Memento  2000

# %%
def gender_reveal(data):
    if data == "Male":
        return 1
    if data == "Femal":
        return 0
    else:
        return np.nan

# %%
data["gender"] = data["gender"].apply(gender_reveal)

# %%
data
# Out:
#       movie_id  budget_mm_$  popularity  revenue_mm_$
# 0        43597       237.00         150       2787.97  \
# 1        43622       200.00         100       1845.03
# 2        43876       100.00         101        520.00
# 3        43879       115.00          38        378.88
# 4        44184        70.00          24         90.00
# ...        ...          ...         ...           ...
# 1460     46859         0.00          14         25.29
# 1461     47023         6.50          11         13.37
# 1462     47524         3.00           5          0.00
# 1463     47962         0.00           0          0.00
# 1464     48229         0.25           1          4.19
#
#                            title  vote_average  vote_count  year month
# 0                         Avatar           7.2       11800  2009   Dec  \
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
data['profit_mm_$'] = data['revenue_mm_$'] - data['budget_mm_$']

# %%
data
# Out:
#       movie_id  budget_mm_$  popularity  revenue_mm_$
# 0        43597       237.00         150       2787.97  \
# 1        43622       200.00         100       1845.03
# 2        43876       100.00         101        520.00
# 3        43879       115.00          38        378.88
# 4        44184        70.00          24         90.00
# ...        ...          ...         ...           ...
# 1460     46859         0.00          14         25.29
# 1461     47023         6.50          11         13.37
# 1462     47524         3.00           5          0.00
# 1463     47962         0.00           0          0.00
# 1464     48229         0.25           1          4.19
#
#                            title  vote_average  vote_count  year month
# 0                         Avatar           7.2       11800  2009   Dec  \
# 1                        Titanic           7.5        7562  1997   Nov
# 2     Terminator 2: Judgment Day           7.7        4185  1991   Jul
# ...

# %%
 def total_profit(data):
        return data['revenue_mm_$'] - data['budget_mm_$']

# %%
data['total_profit_function'] = data[['revenue_mm_$','budget_mm_$']].apply(total_profit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/_libs/index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'revenue_mm_$'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 1
# ...

# %%
pd?
